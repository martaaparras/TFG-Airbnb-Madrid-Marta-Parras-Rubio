# %%
# ============================================
# TFG - Airbnb Madrid
# Ingeniería del Dato
# Marta Parras Rubio
# ============================================

# Librerías básicas
import pandas as pd
import numpy as np

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns

# Requests para APIs
import requests

# Fechas
from datetime import datetime

# Configuración visual
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

sns.set(style="whitegrid")

print("Librerías cargadas correctamente")
# Out:
# Librerías cargadas correctamente

# %%
from google.colab import files
import pandas as pd
import io

uploaded = files.upload()

nombre_archivo = list(uploaded.keys())[0]
print("Archivo subido:", nombre_archivo)

df_airbnb = pd.read_csv(io.BytesIO(uploaded[nombre_archivo]), compression="gzip")

print("Dataset cargado correctamente")
print(df_airbnb.shape)

df_airbnb.head()
# Out:
#      <input type="file" id="files-8fbfdd60-79d9-4b7b-b4e4-34cb97ff3c96" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fbfdd60-79d9-4b7b-b4e4-34cb97ff3c96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_airbnb = pd.read_csv(
    "listings (1).csv.gz",
    compression="gzip"
)

print("Dataset cargado correctamente")
print(df_airbnb.shape)
# Out:
# Dataset cargado correctamente
# (25000, 79)

# %%
import os

os.rename(
    "listings (1).csv.gz",
    "listings.csv.gz"
)

print("Archivo renombrado correctamente")
# Out:
# Archivo renombrado correctamente

# %%
df_airbnb = pd.read_csv(
    "listings.csv.gz",
    compression="gzip"
)

print(df_airbnb.shape)
# Out:
# (25000, 79)

# %%
df_airbnb = pd.read_csv("listings.csv.gz", compression="gzip")

print("Dataset cargado correctamente")
print(df_airbnb.shape)
# Out:
# Dataset cargado correctamente
# (25000, 79)

# %%
df_airbnb = pd.read_csv("listings.csv.gz", compression="gzip")

print("Dataset cargado correctamente")
print(df_airbnb.shape)

df_airbnb.head()
# Out:
# Dataset cargado correctamente
# (25000, 79)
#       id                         listing_url       scrape_id last_scraped  \
# 0  21853  https://www.airbnb.com/rooms/21853  20250914152907   2025-09-15
# 1  30320  https://www.airbnb.com/rooms/30320  20250914152907   2025-09-15
# 2  30959  https://www.airbnb.com/rooms/30959  20250914152907   2025-09-15
# 3  40916  https://www.airbnb.com/rooms/40916  20250914152907   2025-09-15
# 4  62423  https://www.airbnb.com/rooms/62423  20250914152907   2025-09-15
#
#             source                                          name  \
# 0  previous scrape                          Bright and airy room
# 1      city scrape                         Apartamentos Dana Sol
# 2  previous scrape               Beautiful loft in Madrid Center
# 3      city scrape                   Apartasol Apartamentos Dana
# 4      city scrape  MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
#
#                                          description  \
# ...

# %%
# Cargar dataset principal de Airbnb

df_airbnb = pd.read_csv("/content/listings.csv.gz", compression="gzip")

print("Dataset cargado correctamente")
print("Número de filas:", df_airbnb.shape[0])
print("Número de columnas:", df_airbnb.shape[1])

df_airbnb.head()
# Out:
# Dataset cargado correctamente
# Número de filas: 25000
# Número de columnas: 79
#       id                         listing_url       scrape_id last_scraped  \
# 0  21853  https://www.airbnb.com/rooms/21853  20250914152907   2025-09-15
# 1  30320  https://www.airbnb.com/rooms/30320  20250914152907   2025-09-15
# 2  30959  https://www.airbnb.com/rooms/30959  20250914152907   2025-09-15
# 3  40916  https://www.airbnb.com/rooms/40916  20250914152907   2025-09-15
# 4  62423  https://www.airbnb.com/rooms/62423  20250914152907   2025-09-15
#
#             source                                          name  \
# 0  previous scrape                          Bright and airy room
# 1      city scrape                         Apartamentos Dana Sol
# 2  previous scrape               Beautiful loft in Madrid Center
# 3      city scrape                   Apartasol Apartamentos Dana
# 4      city scrape  MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
#
# ...

# %%
# Información general del dataset

df_airbnb.info()
# Ver nombres de columnas

df_airbnb.columns.tolist()
# Valores nulos iniciales

nulos = df_airbnb.isnull().sum().sort_values(ascending=False)
nulos[nulos > 0].head(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            25000 non-null  int64
#  1   listing_url                                   25000 non-null  object
#  2   scrape_id                                     25000 non-null  int64
#  3   last_scraped                                  25000 non-null  object
#  4   source                                        25000 non-null  object
#  5   name                                          25000 non-null  object
#  6   description                                   24130 non-null  object
#  7   neighborhood_overview                         10586 non-null  object
#  8   picture_url                                   24999 non-null  object
# ...

# %%
for col in df_airbnb.columns:
    print(col)
# Out:
# id
# listing_url
# scrape_id
# last_scraped
# source
# name
# description
# neighborhood_overview
# picture_url
# host_id
# host_url
# host_name
# host_since
# host_location
# host_about
# host_response_time
# host_response_rate
# host_acceptance_rate
# host_is_superhost
# host_thumbnail_url
# host_picture_url
# host_neighbourhood
# host_listings_count
# host_total_listings_count
# host_verifications
# host_has_profile_pic
# host_identity_verified
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# latitude
# longitude
# property_type
# room_type
# accommodates
# bathrooms
# bathrooms_text
# bedrooms
# beds
# amenities
# price
# minimum_nights
# maximum_nights
# minimum_minimum_nights
# maximum_minimum_nights
# minimum_maximum_nights
# maximum_maximum_nights
# minimum_nights_avg_ntm
# maximum_nights_avg_ntm
# calendar_updated
# has_availability
# availability_30
# availability_60
# availability_90
# availability_365
# calendar_last_scraped
# number_of_reviews
# ...

# %%
columnas_airbnb = [
    'id',
    'name',
    'host_id',
    'host_name',
    'neighbourhood',
    'latitude',
    'longitude',
    'room_type',
    'price',
    'minimum_nights',
    'number_of_reviews',
    'last_review',
    'reviews_per_month',
    'calculated_host_listings_count',
    'availability_365',
    'number_of_reviews_ltm',
    'license'
]

df = df_airbnb[columnas_airbnb].copy()

df.head()
# Out:
#       id                                          name  host_id  \
# 0  21853                          Bright and airy room    83531
# 1  30320                         Apartamentos Dana Sol   130907
# 2  30959               Beautiful loft in Madrid Center   132883
# 3  40916                   Apartasol Apartamentos Dana   130907
# 4  62423  MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID   303845
#
#          host_name  neighbourhood  latitude  longitude        room_type  \
# 0            Abdel  Madrid, Spain  40.40381   -3.74130     Private room
# 1  Danuta Weronika            NaN  40.41476   -3.70418  Entire home/apt
# 2           Angela            NaN  40.41259   -3.70105  Entire home/apt
# 3  Danuta Weronika            NaN  40.42247   -3.70577  Entire home/apt
# 4           Arturo  Madrid, Spain  40.41884   -3.69655     Private room
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
df_airbnb.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'source',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
# ...

# %%
# Revisar variable precio

df['price'].head()
# Out:
# 0        NaN
# 1    $157.00
# 2        NaN
# 3    $143.00
# 4     $65.00
# Name: price, dtype: object

# %%
# Limpiar variable precio

df['price'] = (
    df['price']
    .astype(str)
    .str.replace('$', '', regex=False)
    .str.replace(',', '', regex=False)
)

df['price'] = pd.to_numeric(df['price'], errors='coerce')

print(df['price'].head())
print(df['price'].dtype)
# Out:
# 0      NaN
# 1    157.0
# 2      NaN
# 3    143.0
# 4     65.0
# Name: price, dtype: float64
# float64

# %%
# Ver cuántos precios nulos tenemos

print("Precios nulos:", df['price'].isnull().sum())
# Out:
# Precios nulos: 6047

# %%
for col in df_airbnb.columns:
    if "neighbour" in col.lower():
        print(col)
# Out:
# host_neighbourhood
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed

# %%
# reviews_per_month

df['reviews_per_month'] = df['reviews_per_month'].fillna(0)

# %%
df['tiene_licencia'] = df['license'].notnull().astype(int)

# %%
df = df.drop(
    columns=[
        'host_name',
        'last_review',
        'license'
    ],
    errors='ignore'
)

# %%
plt.figure(figsize=(10,5))

sns.boxplot(x=df['price'])

plt.title("Boxplot Precio")
plt.show()

# %%
df['price'].describe()
# Out:
# count    18953.000000
# mean       156.691447
# std        492.255350
# min          8.000000
# 25%         70.000000
# 50%        110.000000
# 75%        164.000000
# max      25654.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df[df['price'] < 1000]['price'],
    bins=50
)

plt.title("Distribución del precio (<1000€)")
plt.xlabel("Precio (€)")
plt.ylabel("Frecuencia")

plt.show()

# %%
Q1 = df["price"].quantile(0.25)
Q3 = df["price"].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Límite inferior:", limite_inferior)
print("Límite superior:", limite_superior)
# Out:
# Q1: 70.0
# Q3: 164.0
# IQR: 94.0
# Límite inferior: -71.0
# Límite superior: 305.0

# %%
outliers = df[df["price"] > 305]

print("Número de outliers:", len(outliers))
print("Porcentaje:", round(len(outliers)/len(df)*100,2), "%")
# Out:
# Número de outliers: 1183
# Porcentaje: 4.73 %

# %%
print("Filas antes:", len(df))
# Out:
# Filas antes: 25000

# %%
df_sin_outliers = df[df["price"] <= 305].copy()

print("Filas después:", len(df_sin_outliers))
# Out:
# Filas después: 17770

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df_sin_outliers["price"],
    bins=50
)

plt.title("Distribución del precio después de eliminar outliers")
plt.xlabel("Precio (€)")
plt.ylabel("Frecuencia")

plt.show()

# %%
df = df.dropna(subset=["price"])

# %%
outliers = df[df["price"] > 305]

# %%
outliers = df[df["price"] > 305]

print("Número de outliers:", len(outliers))
print("Porcentaje:", round(len(outliers)/len(df)*100,2), "%")
# Out:
# Número de outliers: 1183
# Porcentaje: 6.24 %

# %%
df_sin_outliers = df[df["price"] <= 305].copy()

print("Filas originales:", len(df))
print("Filas sin outliers:", len(df_sin_outliers))
# Out:
# Filas originales: 25000
# Filas sin outliers: 17770

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df_sin_outliers["price"],
    bins=50
)

plt.title("Distribución del precio tras eliminar outliers")
plt.xlabel("Precio (€)")
plt.ylabel("Frecuencia")

plt.show()

# %%
df = df_sin_outliers.copy()

print(df.shape)
# Out:
# (17770, 15)

# %%
df["ocupacion_estimada"] = 365 - df["availability_365"]

# %%
df["ingresos_potenciales"] = (
    df["price"] *
    df["ocupacion_estimada"]
)

# %%
df["host_profesional"] = (
    df["calculated_host_listings_count"] > 3
).astype(int)

# %%
# Ocupación estimada
df["ocupacion_estimada"] = 365 - df["availability_365"]

# Ingresos potenciales
df["ingresos_potenciales"] = (
    df["price"] *
    df["ocupacion_estimada"]
)

# Host profesional
df["host_profesional"] = (
    df["calculated_host_listings_count"] > 3
).astype(int)

# %%
df[
[
"price",
"availability_365",
"ocupacion_estimada",
"ingresos_potenciales",
"host_profesional"
]
].head()
# Out:
#    price  availability_365  ocupacion_estimada  ingresos_potenciales  \
# 1  157.0               342                  23                3611.0
# 3  143.0               341                  24                3432.0
# 4   65.0               299                  66                4290.0
# 6  116.0               305                  60                6960.0
# 7   79.0               317                  48                3792.0
#
#    host_profesional
# 1                 1
# 3                 1
# 4                 0
# 6                 1
# 7                 1

# %%
df.info()
df.columns.tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17770 entries, 1 to 24999
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              17770 non-null  int64
#  1   name                            17770 non-null  object
#  2   host_id                         17770 non-null  int64
#  3   neighbourhood                   7424 non-null   object
#  4   latitude                        17770 non-null  float64
#  5   longitude                       17770 non-null  float64
#  6   room_type                       17770 non-null  object
#  7   price                           17770 non-null  float64
#  8   minimum_nights                  17770 non-null  int64
#  9   number_of_reviews               17770 non-null  int64
#  10  reviews_per_month               17770 non-null  float64
#  11  calculated_host_listings_count  17770 non-null  int64
# ...

# %%
for col in df_airbnb.columns:
    if "neighbour" in col.lower():
        print(col)
# Out:
# host_neighbourhood
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed

# %%
for col in df_airbnb.columns:
    if any(x in col.lower() for x in [
        "bed",
        "bath",
        "guest",
        "review",
        "superhost",
        "property",
        "accommod"
    ]):
        print(col)
# Out:
# host_is_superhost
# property_type
# accommodates
# bathrooms
# bathrooms_text
# bedrooms
# beds
# number_of_reviews
# number_of_reviews_ltm
# number_of_reviews_l30d
# number_of_reviews_ly
# first_review
# last_review
# review_scores_rating
# review_scores_accuracy
# review_scores_cleanliness
# review_scores_checkin
# review_scores_communication
# review_scores_location
# review_scores_value
# reviews_per_month

# %%
print(len(df_airbnb.columns))
df_airbnb.columns.tolist()
# Out:
# 79
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'source',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
# ...

# %%
columnas_modelo = [
    'id',
    'price',
    'room_type',
    'property_type',
    'neighbourhood_cleansed',
    'neighbourhood_group_cleansed',
    'latitude',
    'longitude',
    'accommodates',
    'bathrooms',
    'bedrooms',
    'beds',
    'minimum_nights',
    'availability_365',
    'number_of_reviews',
    'reviews_per_month',
    'review_scores_rating',
    'review_scores_cleanliness',
    'review_scores_location',
    'review_scores_value',
    'host_is_superhost',
    'instant_bookable',
    'calculated_host_listings_count',
    'license'
]

# %%
variables_nuevas = [
    'accommodates',
    'bathrooms',
    'bedrooms',
    'beds',
    'review_scores_rating',
    'review_scores_cleanliness',
    'review_scores_location',
    'review_scores_value',
    'host_is_superhost',
    'instant_bookable',
    'neighbourhood_cleansed',
    'neighbourhood_group_cleansed'
]

df_airbnb[variables_nuevas].isnull().sum()
# Out:
# accommodates                       0
# bathrooms                       6040
# bedrooms                        2512
# beds                            6035
# review_scores_rating            5147
# review_scores_cleanliness       5148
# review_scores_location          5150
# review_scores_value             5151
# host_is_superhost                668
# instant_bookable                   0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# dtype: int64

# %%
columnas_extra = [
    'accommodates',
    'bedrooms',
    'review_scores_rating',
    'review_scores_location',
    'review_scores_value',
    'host_is_superhost',
    'instant_bookable',
    'neighbourhood_cleansed',
    'neighbourhood_group_cleansed'
]

df_extra = df_airbnb[['id'] + columnas_extra].copy()

# %%
df_extra['host_is_superhost'] = (
    df_extra['host_is_superhost']
    .fillna('f')
)

# %%
df_extra['host_is_superhost'] = (
    df_extra['host_is_superhost'] == 't'
).astype(int)

df_extra['instant_bookable'] = (
    df_extra['instant_bookable'] == 't'
).astype(int)

# %%
df = df.merge(
    df_extra,
    on='id',
    how='left'
)

# %%
print(df.shape)

df.head()
# Out:
# (17770, 27)
#       id                                             name  host_id  \
# 0  30320                            Apartamentos Dana Sol   130907
# 1  40916                      Apartasol Apartamentos Dana   130907
# 2  62423     MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID   303845
# 3  70073             Adorable Apartment Malasaña-Gran Via   353738
# 4  70310  Heart of Malasaña Cozy, Quiet & Sunny Apartment   353738
#
#    neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0            NaN  40.41476   -3.70418  Entire home/apt  157.0               5
# 1            NaN  40.42247   -3.70577  Entire home/apt  143.0               5
# 2  Madrid, Spain  40.41884   -3.69655     Private room   65.0               1
# 3  Madrid, Spain  40.42252   -3.70250  Entire home/apt  116.0              30
# 4  Madrid, Spain  40.42252   -3.70250  Entire home/apt   79.0              30
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
df.to_csv("airbnb_madrid_limpio.csv", index=False)

print("Dataset guardado correctamente")
# Out:
# Dataset guardado correctamente

# %%
df[
[
'accommodates',
'bedrooms',
'review_scores_rating',
'review_scores_location',
'review_scores_value'
]
].describe()
# Out:
#        accommodates      bedrooms  review_scores_rating  \
# count  17770.000000  17740.000000          14945.000000
# mean       3.136297      1.307723              4.629322
# std        1.699760      0.832399              0.479080
# min        1.000000      0.000000              1.000000
# 25%        2.000000      1.000000              4.530000
# 50%        3.000000      1.000000              4.750000
# 75%        4.000000      2.000000              4.900000
# max       16.000000     25.000000              5.000000
#
#        review_scores_location  review_scores_value
# count            14945.000000         14945.000000
# mean                 4.730655             4.532060
# std                  0.377939             0.503861
# min                  1.000000             1.000000
# 25%                  4.640000             4.430000
# 50%                  4.850000             4.640000
# 75%                  4.960000             4.810000
# ...

# %%
df['bedrooms'] = df['bedrooms'].fillna(
    df['bedrooms'].median()
)

# %%
df['review_scores_rating'] = df['review_scores_rating'].fillna(
    df['review_scores_rating'].median()
)

df['review_scores_location'] = df['review_scores_location'].fillna(
    df['review_scores_location'].median()
)

df['review_scores_value'] = df['review_scores_value'].fillna(
    df['review_scores_value'].median()
)

# %%
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# neighbourhood        10346
# name                     0
# id                       0
# host_id                  0
# latitude                 0
# longitude                0
# room_type                0
# price                    0
# minimum_nights           0
# number_of_reviews        0
# dtype: int64

# %%
df['precio_por_huesped'] = (
    df['price'] / df['accommodates']
)

# %%
df['ratio_reviews'] = (
    df['number_of_reviews'] /
    (df['availability_365'] + 1)
)

# %%
df['tipo_host'] = np.where(
    df['host_profesional'] == 1,
    'Profesional',
    'Particular'
)

# %%
df.to_csv(
    "airbnb_madrid_enriquecido.csv",
    index=False
)

print("Dataset enriquecido guardado")
# Out:
# Dataset enriquecido guardado

# %%
df = df.drop(columns=['neighbourhood'])

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(12,6))

sns.histplot(
    df['price'],
    bins=40,
    kde=True
)

plt.title('Distribución de los precios de los alojamientos Airbnb en Madrid')
plt.xlabel('Precio por noche (€)')
plt.ylabel('Frecuencia')

plt.tight_layout()

plt.savefig(
    "grafico_distribucion_precio.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.boxplot(
    data=df,
    x='room_type',
    y='price'
)

plt.title('Distribución del precio según el tipo de alojamiento')
plt.xlabel('Tipo de alojamiento')
plt.ylabel('Precio (€)')

plt.tight_layout()

plt.savefig(
    "grafico_precio_tipo_alojamiento.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
top_barrios = (
    df.groupby('neighbourhood_cleansed')['price']
      .mean()
      .sort_values(ascending=False)
      .head(10)
)

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    x=top_barrios.values,
    y=top_barrios.index
)

plt.title('Top 10 barrios con mayor precio medio')
plt.xlabel('Precio medio (€)')
plt.ylabel('Barrio')

plt.tight_layout()

plt.savefig(
    "grafico_top_barrios.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
precio_capacidad = (
    df.groupby('accommodates')['price']
      .mean()
      .reset_index()
)

plt.figure(figsize=(10,5))

sns.lineplot(
    data=precio_capacidad,
    x='accommodates',
    y='price',
    marker='o'
)

plt.title('Precio medio según capacidad del alojamiento')
plt.xlabel('Capacidad (huéspedes)')
plt.ylabel('Precio medio (€)')

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.boxplot(
    data=df,
    x='host_is_superhost',
    y='price'
)

plt.title('Precio según condición de Superhost')
plt.xlabel('Superhost')
plt.ylabel('Precio (€)')

plt.xticks(
    [0,1],
    ['No','Sí']
)

plt.tight_layout()

plt.savefig(
    "grafico_superhost.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
variables_num = [
    'price',
    'accommodates',
    'bedrooms',
    'availability_365',
    'number_of_reviews',
    'review_scores_rating',
    'review_scores_location',
    'review_scores_value',
    'ocupacion_estimada'
]

corr = df[variables_num].corr()

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    corr,
    annot=True,
    cmap='RdBu_r',
    center=0,
    fmt='.2f'
)

plt.title('Matriz de correlaciones')

plt.tight_layout()

plt.savefig(
    "grafico_correlaciones.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
precio_distrito = (
    df.groupby('neighbourhood_group_cleansed')['price']
      .mean()
      .sort_values(ascending=False)
)

plt.figure(figsize=(12,6))

sns.barplot(
    x=precio_distrito.values,
    y=precio_distrito.index
)

plt.title('Precio medio por distrito de Madrid')
plt.xlabel('Precio medio (€)')
plt.ylabel('Distrito')

plt.show()

# %%
df['neighbourhood_group_cleansed'].value_counts()
# Out:
# neighbourhood_group_cleansed
# Centro                   7411
# Tetuán                   1272
# Salamanca                1164
# Chamberí                 1125
# Arganzuela                885
# Retiro                    696
# Chamartín                 663
# Carabanchel               648
# Ciudad Lineal             596
# Puente de Vallecas        536
# Moncloa - Aravaca         476
# Latina                    418
# Hortaleza                 390
# Usera                     386
# San Blas - Canillejas     362
# Fuencarral - El Pardo     221
# Villaverde                168
# Moratalaz                 117
# Barajas                    98
# Villa de Vallecas          75
# Vicálvaro                  63
# Name: count, dtype: int64

# %%
renta_distritos = pd.DataFrame({
    'neighbourhood_group_cleansed': [
        'Centro',
        'Arganzuela',
        'Retiro',
        'Salamanca',
        'Chamartín',
        'Tetuán',
        'Chamberí',
        'Fuencarral - El Pardo',
        'Moncloa - Aravaca',
        'Latina',
        'Carabanchel',
        'Usera',
        'Puente de Vallecas',
        'Moratalaz',
        'Ciudad Lineal',
        'Hortaleza',
        'Villaverde',
        'Villa de Vallecas',
        'Vicálvaro',
        'San Blas - Canillejas',
        'Barajas'
    ],

    'renta_media': [
        38000,
        35000,
        52000,
        65000,
        61000,
        33000,
        55000,
        45000,
        60000,
        30000,
        28000,
        27000,
        25000,
        32000,
        36000,
        42000,
        24000,
        26000,
        29000,
        34000,
        47000
    ]
})

# %%
renta_distritos.head()
# Out:
#   neighbourhood_group_cleansed  renta_media
# 0                       Centro        38000
# 1                   Arganzuela        35000
# 2                       Retiro        52000
# 3                    Salamanca        65000
# 4                    Chamartín        61000

# %%
df = df.merge(
    renta_distritos,
    on='neighbourhood_group_cleansed',
    how='left'
)

# %%
print(df.shape)

df[['neighbourhood_group_cleansed',
    'renta_media']].head()
# Out:
# (17770, 30)
#   neighbourhood_group_cleansed  renta_media
# 0                       Centro        38000
# 1                       Centro        38000
# 2                       Centro        38000
# 3                       Centro        38000
# 4                       Centro        38000

# %%
df['renta_media'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (17770, 30)

# %%
df['renta_media'].isnull().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x='renta_media',
    y='price',
    alpha=0.4
)

plt.title('Relación entre renta media del distrito y precio del alojamiento')
plt.xlabel('Renta media (€)')
plt.ylabel('Precio (€)')

plt.show()

# %%
df.columns.tolist()
# Out:
# ['id',
#  'name',
#  'host_id',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'tiene_licencia',
#  'ocupacion_estimada',
#  'ingresos_potenciales',
#  'host_profesional',
#  'accommodates',
#  'bedrooms',
#  'review_scores_rating',
#  'review_scores_location',
#  'review_scores_value',
#  'host_is_superhost',
#  'instant_bookable',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'precio_por_huesped',
#  'ratio_reviews',
#  'tipo_host',
#  'renta_media']

# %%
df_airbnb.shape
# Out:
# (25000, 79)

# %%
X = pd.get_dummies(
    X,
    columns=[
        'room_type',
        'neighbourhood_group_cleansed'
    ],
    drop_first=True
)

print(X.shape)
# Out:
# (17770, 41)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (14216, 41)
# (3554, 41)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

modelo_lineal = LinearRegression()

modelo_lineal.fit(
    X_train_scaled,
    y_train
)
# Out:
# LinearRegression()

# %%
y_pred_lineal = modelo_lineal.predict(
    X_test_scaled
)

# %%
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error
)

import numpy as np

r2 = r2_score(
    y_test,
    y_pred_lineal
)

mae = mean_absolute_error(
    y_test,
    y_pred_lineal
)

rmse = np.sqrt(
    mean_squared_error(
        y_test,
        y_pred_lineal
    )
)

print("R²:", round(r2,4))
print("MAE:", round(mae,2))
print("RMSE:", round(rmse,2))
# Out:
# R²: 0.8306
# MAE: 16.82
# RMSE: 25.83

# %%
plt.figure(figsize=(8,8))

plt.scatter(
    y_test,
    y_pred_lineal,
    alpha=0.4
)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    'r--'
)

plt.title('Regresión Lineal: Valores reales vs predichos')
plt.xlabel('Precio real (€)')
plt.ylabel('Precio predicho (€)')

plt.tight_layout()
plt.show()

# %%
errores = y_test - y_pred_lineal

plt.figure(figsize=(10,6))

sns.histplot(
    errores,
    bins=40,
    kde=True
)

plt.title('Distribución de los errores de predicción')
plt.xlabel('Error (€)')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    y_pred_lineal,
    errores,
    alpha=0.4
)

plt.axhline(
    y=0,
    color='red',
    linestyle='--'
)

plt.title('Residuos frente a valores predichos')
plt.xlabel('Precio predicho (€)')
plt.ylabel('Residuo')

plt.tight_layout()
plt.show()

# %%
renta_distritos = pd.DataFrame({
    'neighbourhood_group_cleansed': [
        'Centro','Arganzuela','Retiro','Salamanca','Chamartín',
        'Tetuán','Chamberí','Fuencarral - El Pardo',
        'Moncloa - Aravaca','Latina','Carabanchel','Usera',
        'Puente de Vallecas','Moratalaz','Ciudad Lineal',
        'Hortaleza','Villaverde','Villa de Vallecas',
        'Vicálvaro','San Blas - Canillejas','Barajas'
    ],
    'renta_media': [
        38000,35000,52000,65000,61000,
        33000,55000,45000,60000,30000,
        28000,27000,25000,32000,36000,
        42000,24000,26000,29000,34000,47000
    ]
})

# %%
df = df.merge(
    renta_distritos,
    on='neighbourhood_group_cleansed',
    how='left'
)

# %%
df['renta_media'].isnull().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(8,8))

plt.scatter(
    y_test,
    y_pred_lineal,
    alpha=0.4
)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    'r--'
)

plt.title('Valores reales vs valores predichos')
plt.xlabel('Precio real (€)')
plt.ylabel('Precio predicho (€)')

plt.tight_layout()
plt.show()

# %%
errores = y_test - y_pred_lineal

plt.figure(figsize=(10,6))

sns.histplot(
    errores,
    bins=40,
    kde=True
)

plt.title('Distribución de errores de predicción')
plt.xlabel('Error (€)')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    y_pred_lineal,
    errores,
    alpha=0.4
)

plt.axhline(
    y=0,
    color='red',
    linestyle='--'
)

plt.title('Residuos frente a valores predichos')
plt.xlabel('Precio predicho (€)')
plt.ylabel('Residuo')

plt.tight_layout()
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=300,
    max_depth=15,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

r2_rf = r2_score(y_test, y_pred_rf)

mae_rf = mean_absolute_error(y_test, y_pred_rf)

rmse_rf = np.sqrt(
    mean_squared_error(
        y_test,
        y_pred_rf
    )
)

print("R²:", round(r2_rf,4))
print("MAE:", round(mae_rf,2))
print("RMSE:", round(rmse_rf,2))
# Out:
# R²: 0.9974
# MAE: 0.5
# RMSE: 3.21

# %%
X.columns.tolist()
# Out:
# ['id',
#  'accommodates',
#  'bedrooms',
#  'minimum_nights',
#  'availability_365',
#  'number_of_reviews',
#  'reviews_per_month',
#  'review_scores_rating',
#  'review_scores_location',
#  'review_scores_value',
#  'host_is_superhost',
#  'instant_bookable',
#  'calculated_host_listings_count',
#  'tiene_licencia',
#  'host_profesional',
#  'ocupacion_estimada',
#  'precio_por_huesped',
#  'ratio_reviews',
#  'room_type_Hotel room',
#  'room_type_Private room',
#  'room_type_Shared room',
#  'neighbourhood_group_cleansed_Barajas',
#  'neighbourhood_group_cleansed_Carabanchel',
#  'neighbourhood_group_cleansed_Centro',
#  'neighbourhood_group_cleansed_Chamartín',
#  'neighbourhood_group_cleansed_Chamberí',
#  'neighbourhood_group_cleansed_Ciudad Lineal',
#  'neighbourhood_group_cleansed_Fuencarral - El Pardo',
#  'neighbourhood_group_cleansed_Hortaleza',
#  'neighbourhood_group_cleansed_Latina',
#  'neighbourhood_group_cleansed_Moncloa - Aravaca',
# ...

# %%
X = X.drop(columns=['precio_por_huesped'])

# %%
X.shape
# Out:
# (17770, 40)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=300,
    max_depth=15,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

r2_rf = r2_score(y_test, y_pred_rf)

mae_rf = mean_absolute_error(y_test, y_pred_rf)

rmse_rf = np.sqrt(
    mean_squared_error(
        y_test,
        y_pred_rf
    )
)

print("R²:", round(r2_rf,4))
print("MAE:", round(mae_rf,2))
print("RMSE:", round(rmse_rf,2))
# Out:
# R²: 0.6692
# MAE: 25.79
# RMSE: 36.09

# %%
# Comprobación final de variables usadas en modelización

print("Dimensiones del dataset df:", df.shape)
print("Dimensiones de X antes/después de codificación:", X.shape)
print("Dimensiones de y:", y.shape)

print("\nVariables utilizadas en X:")
for i, col in enumerate(X.columns, start=1):
    print(f"{i}. {col}")

print("\nNúmero total de variables predictoras:", len(X.columns))

print("\nDimensiones del conjunto de entrenamiento:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("\nDimensiones del conjunto de prueba:")
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# Dimensiones del dataset df: (17770, 24)
# Dimensiones de X antes/después de codificación: (17770, 40)
# Dimensiones de y: (17770,)
#
# Variables utilizadas en X:
# 1. id
# 2. accommodates
# 3. bedrooms
# 4. minimum_nights
# 5. availability_365
# 6. number_of_reviews
# 7. reviews_per_month
# 8. review_scores_rating
# 9. review_scores_location
# 10. review_scores_value
# 11. host_is_superhost
# 12. instant_bookable
# 13. calculated_host_listings_count
# 14. tiene_licencia
# 15. host_profesional
# 16. ocupacion_estimada
# 17. ratio_reviews
# 18. room_type_Hotel room
# 19. room_type_Private room
# 20. room_type_Shared room
# 21. neighbourhood_group_cleansed_Barajas
# 22. neighbourhood_group_cleansed_Carabanchel
# 23. neighbourhood_group_cleansed_Centro
# 24. neighbourhood_group_cleansed_Chamartín
# 25. neighbourhood_group_cleansed_Chamberí
# 26. neighbourhood_group_cleansed_Ciudad Lineal
# 27. neighbourhood_group_cleansed_Fuencarral - El Pardo
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=500,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

print("R²:", round(r2_score(y_test, y_pred_rf),4))
print("MAE:", round(mean_absolute_error(y_test, y_pred_rf),2))
print("RMSE:", round(np.sqrt(mean_squared_error(y_test, y_pred_rf)),2))
# Out:
# R²: 0.6757
# MAE: 25.31
# RMSE: 35.73

# %%
# ===============================
# ANÁLISIS DEL DATO - DATASET FINAL
# ===============================

variables_modelo = [
    'room_type',
    'neighbourhood_group_cleansed',
    'accommodates',
    'bedrooms',
    'minimum_nights',
    'availability_365',
    'number_of_reviews',
    'reviews_per_month',
    'review_scores_rating',
    'review_scores_location',
    'review_scores_value',
    'host_is_superhost',
    'instant_bookable',
    'tiene_licencia',
    'host_profesional',
    'ocupacion_estimada',
    'ratio_reviews',
    'renta_media'
]

X = df[variables_modelo].copy()
y = df['price'].copy()

print("X:", X.shape)
print("y:", y.shape)
print("Nulos en X:", X.isnull().sum().sum())
# Out:
# X: (17770, 18)
# y: (17770,)
# Nulos en X: 0

# %%
X = pd.get_dummies(
    X,
    columns=[
        'room_type',
        'neighbourhood_group_cleansed'
    ],
    drop_first=True
)

print("X tras One Hot Encoding:", X.shape)
# Out:
# X tras One Hot Encoding: (17770, 39)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
# Out:
# X_train: (14216, 39)
# X_test: (3554, 39)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
# Out:
# X_train: (14216, 39)
# X_test: (3554, 39)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

resultados = []

def evaluar_modelo(nombre, y_test, y_pred):

    r2 = r2_score(y_test, y_pred)

    mae = mean_absolute_error(y_test, y_pred)

    rmse = np.sqrt(
        mean_squared_error(y_test, y_pred)
    )

    resultados.append({
        'Modelo': nombre,
        'R2': r2,
        'MAE': mae,
        'RMSE': rmse
    })

    print(nombre)
    print("R²:", round(r2,4))
    print("MAE:", round(mae,2))
    print("RMSE:", round(rmse,2))

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

modelo_lineal = LinearRegression()
modelo_lineal.fit(X_train_scaled, y_train)

y_pred_lineal = modelo_lineal.predict(X_test_scaled)

evaluar_modelo("Regresión Lineal", y_test, y_pred_lineal)
# Out:
# Regresión Lineal
# R²: 0.5376
# MAE: 31.47
# RMSE: 42.67

# %%
y_pred_lineal = modelo_lineal.predict(X_test_scaled)

evaluar_modelo(
    "Regresión Lineal",
    y_test,
    y_pred_lineal
)
# Out:
# Regresión Lineal
# R²: 0.5376
# MAE: 31.47
# RMSE: 42.67

# %%
from sklearn.ensemble import RandomForestRegressor

modelo_rf = RandomForestRegressor(
    n_estimators=300,
    max_depth=20,
    min_samples_split=5,
    min_samples_leaf=2,
    random_state=42,
    n_jobs=-1
)

modelo_rf.fit(X_train, y_train)

y_pred_rf = modelo_rf.predict(X_test)

evaluar_modelo("Random Forest", y_test, y_pred_rf)
# Out:
# Random Forest
# R²: 0.6576
# MAE: 25.91
# RMSE: 36.72

# %%
resultados_df = pd.DataFrame(resultados)

resultados_df['R2'] = resultados_df['R2'].round(4)
resultados_df['MAE'] = resultados_df['MAE'].round(2)
resultados_df['RMSE'] = resultados_df['RMSE'].round(2)

resultados_df
# Out:
#              Modelo      R2    MAE   RMSE
# 0  Regresión Lineal  0.5376  31.47  42.67
# 1  Regresión Lineal  0.5376  31.47  42.67
# 2     Random Forest  0.6576  25.91  36.72

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=resultados_df,
    x='Modelo',
    y='R2'
)

plt.title('Comparación del rendimiento de los modelos')
plt.xlabel('Modelo')
plt.ylabel('R²')

plt.ylim(0, 1)

plt.tight_layout()
plt.savefig("comparacion_modelos_r2.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
resultados_error = resultados_df.melt(
    id_vars='Modelo',
    value_vars=['MAE', 'RMSE'],
    var_name='Métrica',
    value_name='Error'
)

plt.figure(figsize=(10,6))

sns.barplot(
    data=resultados_error,
    x='Modelo',
    y='Error',
    hue='Métrica'
)

plt.title('Comparación de errores entre modelos')
plt.xlabel('Modelo')
plt.ylabel('Error (€)')

plt.tight_layout()
plt.savefig("comparacion_modelos_error.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# ============================================
# MODELO 3: GRADIENT BOOSTING REGRESSOR
# ============================================

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

modelo_gb = GradientBoostingRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=4,
    random_state=42
)

modelo_gb.fit(X_train, y_train)

y_pred_gb = modelo_gb.predict(X_test)

r2_gb = r2_score(y_test, y_pred_gb)
mae_gb = mean_absolute_error(y_test, y_pred_gb)
rmse_gb = np.sqrt(mean_squared_error(y_test, y_pred_gb))

print("Gradient Boosting")
print("R²:", round(r2_gb, 4))
print("MAE:", round(mae_gb, 2))
print("RMSE:", round(rmse_gb, 2))
# Out:
# Gradient Boosting
# R²: 0.6276
# MAE: 27.63
# RMSE: 38.29

# %%
# ============================================
# TABLA FINAL DE RESULTADOS
# ============================================

resultados_df = pd.DataFrame({
    "Modelo": [
        "Regresión Lineal",
        "Random Forest",
        "Gradient Boosting"
    ],
    "R2": [
        r2_score(y_test, y_pred_lineal),
        r2_score(y_test, y_pred_rf),
        r2_score(y_test, y_pred_gb)
    ],
    "MAE": [
        mean_absolute_error(y_test, y_pred_lineal),
        mean_absolute_error(y_test, y_pred_rf),
        mean_absolute_error(y_test, y_pred_gb)
    ],
    "RMSE": [
        np.sqrt(mean_squared_error(y_test, y_pred_lineal)),
        np.sqrt(mean_squared_error(y_test, y_pred_rf)),
        np.sqrt(mean_squared_error(y_test, y_pred_gb))
    ]
})

resultados_df["R2"] = resultados_df["R2"].round(4)
resultados_df["MAE"] = resultados_df["MAE"].round(2)
resultados_df["RMSE"] = resultados_df["RMSE"].round(2)

resultados_df
# Out:
#               Modelo      R2    MAE   RMSE
# 0   Regresión Lineal  0.5376  31.47  42.67
# 1      Random Forest  0.6576  25.91  36.72
# 2  Gradient Boosting  0.6276  27.63  38.29

# %%
# ============================================
# SELECCIÓN AUTOMÁTICA DEL MEJOR MODELO
# ============================================

mejor_modelo_nombre = resultados_df.sort_values(
    by="RMSE",
    ascending=True
).iloc[0]["Modelo"]

if mejor_modelo_nombre == "Gradient Boosting":
    mejor_pred = y_pred_gb
elif mejor_modelo_nombre == "Random Forest":
    mejor_pred = y_pred_rf
else:
    mejor_pred = y_pred_lineal

print("Mejor modelo:", mejor_modelo_nombre)
# Out:
# Mejor modelo: Random Forest

# %%
[x for x in globals() if "pred" in x]
# Out:
# ['y_pred_lineal', 'y_pred_rf', 'y_pred_gb', 'mejor_pred']

# %%
plt.figure(figsize=(8,8))

plt.scatter(
    y_test,
    mejor_pred,
    alpha=0.4
)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    'r--'
)

plt.title(f'"Random Forest": valores reales vs predichos')
plt.xlabel('Precio real (€)')
plt.ylabel('Precio predicho (€)')

plt.tight_layout()
plt.savefig("mejor_modelo_reales_vs_predichos.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
importancias_rf = pd.DataFrame({
    'Variable': X.columns,
    'Importancia': modelo_rf.feature_importances_
}).sort_values(by='Importancia', ascending=False).head(15)

importancias_rf
# Out:
#                   Variable  Importancia
# 17  room_type_Private room     0.281346
# 1                 bedrooms     0.119288
# 0             accommodates     0.072599
# 15             renta_media     0.065995
# 5        reviews_per_month     0.060561
# 2           minimum_nights     0.051071
# 3         availability_365     0.041096
# 13      ocupacion_estimada     0.040817
# 7   review_scores_location     0.038868
# 14           ratio_reviews     0.035307
# 6     review_scores_rating     0.032424
# 10        instant_bookable     0.030119
# 8      review_scores_value     0.029103
# 4        number_of_reviews     0.028803
# 12        host_profesional     0.012415

# %%
plt.figure(figsize=(10,7))

sns.barplot(
    data=importancias_rf,
    x='Importancia',
    y='Variable'
)

plt.title('Top 15 variables más importantes - Random Forest')
plt.xlabel('Importancia')
plt.ylabel('Variable')

plt.tight_layout()
plt.savefig("importancia_variables_random_forest.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
gb = GradientBoostingRegressor(random_state=42)
gb.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
import pandas as pd

importancias_gb = pd.DataFrame({
    'Variable': X.columns,
    'Importancia': gb.feature_importances_
})

importancias_gb = importancias_gb.sort_values(
    by='Importancia',
    ascending=False
).head(15)

# %%
plt.figure(figsize=(10,7))

sns.barplot(
    data=importancias_gb,
    x='Importancia',
    y='Variable'
)

plt.title('Top 15 variables más importantes - Gradient Boosting')
plt.xlabel('Importancia')
plt.ylabel('Variable')

plt.tight_layout()
plt.savefig("importancia_variables_gradient_boosting.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
df.to_csv("airbnb_madrid_dataset_final.csv", index=False)
resultados_df.to_csv("resultados_modelos.csv", index=False)

print("Archivos guardados correctamente")
# Out:
# Archivos guardados correctamente

# %%
# ============================================
# GRÁFICOS FINALES PROFESIONALES - ANÁLISIS DEL DATO
# ============================================

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

sns.set_theme(style="whitegrid", context="talk")

# Limpiar resultados duplicados
resultados_df = resultados_df.drop_duplicates(subset='Modelo', keep='last').reset_index(drop=True)

# Ordenar modelos
orden_modelos = ['Regresión Lineal', 'Gradient Boosting', 'Random Forest']
resultados_df['Modelo'] = pd.Categorical(resultados_df['Modelo'], categories=orden_modelos, ordered=True)
resultados_df = resultados_df.sort_values('Modelo')

resultados_df
# Out:
#               Modelo      R2    MAE   RMSE
# 0   Regresión Lineal  0.5376  31.47  42.67
# 2  Gradient Boosting  0.6276  27.63  38.29
# 1      Random Forest  0.6576  25.91  36.72

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(
    data=resultados_df,
    x='Modelo',
    y='R2',
    palette='Blues_d'
)

for p in ax.patches:
    ax.annotate(
        f"{p.get_height():.3f}",
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center',
        va='bottom',
        fontsize=12
    )

plt.title('Comparación de la capacidad explicativa de los modelos', fontsize=16, weight='bold')
plt.xlabel('Modelo')
plt.ylabel('R²')
plt.ylim(0, 0.8)

plt.tight_layout()
plt.savefig("figura_comparacion_r2_modelos.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_1544/1439779543.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
resultados_error = resultados_df.melt(
    id_vars='Modelo',
    value_vars=['MAE', 'RMSE'],
    var_name='Métrica',
    value_name='Error'
)

plt.figure(figsize=(11,6))

ax = sns.barplot(
    data=resultados_error,
    x='Modelo',
    y='Error',
    hue='Métrica',
    palette='Set2'
)

for p in ax.patches:
    ax.annotate(
        f"{p.get_height():.2f}",
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.title('Comparación de errores predictivos entre modelos', fontsize=16, weight='bold')
plt.xlabel('Modelo')
plt.ylabel('Error medio (€)')
plt.legend(title='Métrica')

plt.tight_layout()
plt.savefig("figura_comparacion_errores_modelos.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8,8))

plt.scatter(
    y_test,
    y_pred_rf,
    alpha=0.35,
    s=35
)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle='--',
    linewidth=2,
    color='red'
)

plt.title('Random Forest: precios reales vs precios predichos', fontsize=16, weight='bold')
plt.xlabel('Precio real (€)')
plt.ylabel('Precio predicho (€)')

plt.tight_layout()
plt.savefig("figura_random_forest_reales_vs_predichos.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
errores_rf = y_test - y_pred_rf

plt.figure(figsize=(10,6))

sns.histplot(
    errores_rf,
    bins=40,
    kde=True
)

plt.axvline(
    0,
    color='red',
    linestyle='--'
)

plt.title('Distribución de errores - Random Forest')
plt.xlabel('Error (€)')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %%
errores_rf = y_test - y_pred_rf

plt.figure(figsize=(10,6))

sns.histplot(
    errores_rf,
    bins=40,
    kde=True,
    color='#4C72B0'
)

plt.axvline(0, color='red', linestyle='--', linewidth=2)

plt.title('Distribución de los errores del modelo Random Forest', fontsize=16, weight='bold')
plt.xlabel('Error de predicción (€)')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.savefig("figura_errores_random_forest.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
importancias_rf = pd.DataFrame({
    'Variable': X.columns,
    'Importancia': modelo_rf.feature_importances_
}).sort_values(by='Importancia', ascending=False).head(15)

plt.figure(figsize=(11,7))

sns.barplot(
    data=importancias_rf,
    x='Importancia',
    y='Variable',
    palette='viridis'
)

plt.title('Top 15 variables más importantes en el modelo Random Forest', fontsize=16, weight='bold')
plt.xlabel('Importancia relativa')
plt.ylabel('Variable')

plt.tight_layout()
plt.savefig("figura_importancia_variables_random_forest.png", dpi=300, bbox_inches='tight')
plt.show()

importancias_rf
# Out:
# /tmp/ipykernel_1544/3496274861.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
#                   Variable  Importancia
# 17  room_type_Private room     0.281346
# 1                 bedrooms     0.119288
# 0             accommodates     0.072599
# 15             renta_media     0.065995
# 5        reviews_per_month     0.060561
# 2           minimum_nights     0.051071
# 3         availability_365     0.041096
# 13      ocupacion_estimada     0.040817
# 7   review_scores_location     0.038868
# 14           ratio_reviews     0.035307
# 6     review_scores_rating     0.032424
# 10        instant_bookable     0.030119
# 8      review_scores_value     0.029103
# 4        number_of_reviews     0.028803
# 12        host_profesional     0.012415

# %%
resultados_df.to_csv("resultados_finales_modelos.csv", index=False)
importancias_rf.to_csv("importancia_variables_random_forest.csv", index=False)
df.to_csv("airbnb_madrid_dataset_final.csv", index=False)

print("Archivos finales guardados correctamente")
# Out:
# Archivos finales guardados correctamente

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

tabla_rl = pd.DataFrame({
    "Métrica": [
        "MAE",
        "RMSE",
        "R²"
    ],

    "Valor": [
        round(mean_absolute_error(y_test, y_pred_lr), 2),
        round(np.sqrt(mean_squared_error(y_test, y_pred_lr)), 2),
        round(r2_score(y_test, y_pred_lr), 3)
    ]
})

tabla_rl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1544/692840025.py in <cell line: 0>()
#      13
#      14     "Valor": [
# ---> 15         round(mean_absolute_error(y_test, y_pred_lr), 2),
#      16         round(np.sqrt(mean_squared_error(y_test, y_pred_lr)), 2),
#      17         round(r2_score(y_test, y_pred_lr), 3)
#
# NameError: name 'y_pred_lr' is not defined

# %%
# Comprobación final de variables usadas en modelización

print("Dimensiones del dataset df:", df.shape)
print("Dimensiones de X antes/después de codificación:", X.shape)
print("Dimensiones de y:", y.shape)

print("\nVariables utilizadas en X:")
for i, col in enumerate(X.columns, start=1):
    print(f"{i}. {col}")

print("\nNúmero total de variables predictoras:", len(X.columns))

print("\nDimensiones del conjunto de entrenamiento:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("\nDimensiones del conjunto de prueba:")
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# Dimensiones del dataset df: (17770, 24)
# Dimensiones de X antes/después de codificación: (17770, 39)
# Dimensiones de y: (17770,)
#
# Variables utilizadas en X:
# 1. accommodates
# 2. bedrooms
# 3. minimum_nights
# 4. availability_365
# 5. number_of_reviews
# 6. reviews_per_month
# 7. review_scores_rating
# 8. review_scores_location
# 9. review_scores_value
# 10. host_is_superhost
# 11. instant_bookable
# 12. tiene_licencia
# 13. host_profesional
# 14. ocupacion_estimada
# 15. ratio_reviews
# 16. renta_media
# 17. room_type_Hotel room
# 18. room_type_Private room
# 19. room_type_Shared room
# 20. neighbourhood_group_cleansed_Barajas
# 21. neighbourhood_group_cleansed_Carabanchel
# 22. neighbourhood_group_cleansed_Centro
# 23. neighbourhood_group_cleansed_Chamartín
# 24. neighbourhood_group_cleansed_Chamberí
# 25. neighbourhood_group_cleansed_Ciudad Lineal
# 26. neighbourhood_group_cleansed_Fuencarral - El Pardo
# 27. neighbourhood_group_cleansed_Hortaleza
# ...

# %%
print(df.columns.tolist())
print(len(df.columns))
# Out:
# ['id', 'price', 'room_type', 'neighbourhood_group_cleansed', 'accommodates', 'bedrooms', 'minimum_nights', 'availability_365', 'number_of_reviews', 'reviews_per_month', 'review_scores_rating', 'review_scores_location', 'review_scores_value', 'host_is_superhost', 'instant_bookable', 'calculated_host_listings_count', 'tiene_licencia', 'host_profesional', 'ocupacion_estimada', 'precio_por_huesped', 'ratio_reviews', 'renta_media_x', 'renta_media_y', 'renta_media']
# 24

# %%
df = df.drop(columns=['renta_media_x', 'renta_media_y'])

# %%
print(df.shape)
# Out:
# (17770, 22)
